# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json("./russian_ads.json")

# %%
df.head(5)
# Out:
#    ad_clicks                                            ad_copy  \
# 0         43          "Free Figure's Black Power Rally at VCU:"
# 1         47  A woman pretended Afro-American to gain contro...
# 2         47  2Pac believed in FightTupac Shakur was indeed ...
# 3         10  Today we celebrate the legendary rapper who ev...
# 4         26  It is an American history. African-American ci...
#
#   ad_creation_date ad_end_date  ad_id  ad_impressions  \
# 0       06/15/2015  06/16/2015  331.0           764.0
# 1       06/15/2015  06/16/2015  332.0           676.0
# 2       06/16/2015  06/17/2015  333.0          1075.0
# 3       06/16/2015  06/17/2015  334.0           153.0
# 4       06/16/2015  06/17/2015  335.0           476.0
#
#                                      ad_landing_page  ad_spend_rub  \
# 0  https://www.facebook.com/Black-Matters-1579673...         90.86
# 1  https://www.facebook.com/Black-Matters-1579673...         89.51
# 2  https://www.facebook.com/Black-Matters-1579673...        174.40
# 3  https://www.facebook.com/Black-Matters-1579673...         90.07
# 4  https://www.facebook.com/Black-Matters-1579673...         84.15
#
#    ad_spend_usd                              ad_targeting_location   ...    \
# 0          1.66  United States: Baltimore Maryland: Ferguson, S...   ...
# 1          1.63  United States: Baltimore Maryland; Ferguson, S...   ...
# 2          3.21  United States: Baltimore Maryland; Ferguson, S...   ...
# 3          1.66  United States: Baltimore Maryland: Ferguson, S...   ...
# 4          1.55  United States: Baltimore Maryland; Ferguson, S...   ...
#
#   interests_categories_regex  language  language_categories  \
# 0                                 None      [Not Specified]
# 1                                 None      [Not Specified]
# 2                                 None      [Not Specified]
# 3           African American      None      [Not Specified]
# 4                                 None      [Not Specified]
#
#    location_categories  location_categories_regex  month  \
# 0  [Midwest, Atlantic]           Midwest_Atlantic   [06]
# 1  [Midwest, Atlantic]           Midwest_Atlantic   [06]
# 2  [Midwest, Atlantic]           Midwest_Atlantic   [06]
# 3  [Midwest, Atlantic]           Midwest_Atlantic   [06]
# 4  [Midwest, Atlantic]           Midwest_Atlantic   [06]
#
#             pdf_filepath  placement_categories  \
# 0  2015-06/P10002117.pdf            [Facebook]
# 1  2015-06/P10002118.pdf            [Facebook]
# 2  2015-06/P10002119.pdf            [Facebook]
# 3  2015-06/P10002120.pdf            [Facebook]
# 4  2015-06/P10002121.pdf            [Facebook]
#
#                                           placements    year
# 0  News Feed on desktop computers or News Feed on...  [2015]
# 1  News Feed on desktop computers or News Feed on...  [2015]
# 2  News Feed on desktop computers or News Feed on...  [2015]
# 3  News Feed on desktop computers or News Feed on...  [2015]
# 4  News Feed on desktop computers or News Feed on...  [2015]
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#           ad_clicks        ad_id  ad_impressions   ad_spend_rub  ad_spend_usd  \
# count   3517.000000  3366.000000    3.514000e+03    2730.000000   2730.000000
# mean    1061.688655  1708.480095    1.154021e+04    2152.026484     33.955451
# std     3376.498875  1005.571728    4.544945e+04   10178.730781    170.349380
# min        0.000000     1.000000    0.000000e+00       0.000000      0.000000
# 25%        0.000000   842.250000    0.000000e+00     100.000000      1.602500
# 50%       70.000000  1683.500000    1.034500e+03     300.000000      4.900000
# 75%      827.000000  2550.750000    8.428000e+03     700.000000     10.750000
# max    73063.000000  3519.000000    1.334544e+06  331675.750000   6100.210000
#
#          age_lower    age_upper  conversion_rate  date_order_index  \
# count  3516.000000  3516.000000      2600.000000       3517.000000
# mean     17.773606   829.393060         0.102435       1758.000000
# std       2.726394   364.857044         0.078389       1015.414776
# min      13.000000    17.000000         0.000000          0.000000
# 25%      18.000000   999.000000         0.050000        879.000000
# 50%      18.000000   999.000000         0.100000       1758.000000
# 75%      18.000000   999.000000         0.150000       2637.000000
# max      45.000000   999.000000         1.690000       3516.000000
#
#                day  efficiency_clicks  efficiency_impressions
# count  3517.000000        2548.000000             2545.000000
# mean     14.906739         184.536016             1450.455847
# std       7.478779         402.649345             3559.251916
# min       1.000000           0.000000                1.860000
# 25%      10.000000           7.160000              160.750000
# 50%      14.000000          33.760000              408.700000
# 75%      21.000000         196.697500             1334.090000
# max      31.000000        7726.070000            93832.950000

# %%
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# ad_clicks                        0
# ad_copy                         40
# ad_creation_date                 2
# ad_end_date                   1144
# ad_id                          151
# ad_impressions                   3
# ad_landing_page                 29
# ad_spend_rub                   787
# ad_spend_usd                   787
# ad_targeting_location           31
# age                              1
# age_lower                        1
# age_upper                        1
# conversion_rate                917
# date_order_index                 0
# day                              0
# efficiency_clicks              969
# efficiency_impressions         972
# excluded_connections          2559
# extra_data                       1
# image_filepath                   0
# interest_expansion             292
# interests_categories             0
# interests_categories_regex       0
# language                      1909
# language_categories              0
# location_categories              0
# location_categories_regex        0
# month                            0
# pdf_filepath                     0
# placement_categories             0
# placements                       0
# year                             0
# dtype: int64

# %%
# Create figure with two subplots
fig = plt.figure(figsize=(16,4))

# Plot LoanAmount
ax1 = fig.add_subplot(1, 2, 1)
ax1.set_title("Histogram of Ad Clicks")
ax1.set_xlabel('Clicks')
ax1.set_ylabel('No. ads')
df['ad_clicks'].hist(bins=20)

# %%
df.plot.scatter(x='ad_spend_usd', y='ad_impressions')
